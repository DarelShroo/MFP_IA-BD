# %% [markdown]
# # Plantilla para la Tarea Online BDA01
#
# ## Nombre del alumno:

# %% [markdown]
# El objetivo de esta tarea es que despliegues el entorno de Hadoop que vamos a usar en el resto de unidades. Para ello debes realizar paso a paso el proceso que se explicó en la guía práctica. Después podrás entregar esta plantilla sustituyendo las celdas de markdown o de código por lo que se pide. Lee detenidamente el enunciado ya que a veces se pedirá que incluyas una imagen, otras texto y en algunas código ejecutable. El libro de Jupyter que entregues deberá tener las celdas completamente ejecutadas en orden secuencial, no debe tener errores y corresponderá con la ejecución real que obtuviste al ejecutarlo en el contenedor `namenode` de tu equipo.

# %% [markdown]
# Comienza copiando este libro, `Tarea\ para\ BDA01.ipynb`, en el servidor de Jupyter. Recuerda que el directorio `notebooks` del anfitrión está montado en el directorio `/media/notebooks` del contenedor llamado `namenode` de `docker`. Cualquier cosa que sitúes en este directorio (o en un subdirectorio) será accesible tanto por el anfitrión como por el contenedor.
#
# Si el anterior párrafo no tiene sentido para ti, probablemente debas revisar de nuevo la guía práctica antes de seguir con la tarea práctica.
#
# Es posible que al intentar copiar el libro `Tarea\ para\ BDA01.ipynb` tengas un problema de permisos. Si esto sucede es porque el contenedor de `docker` está asignando la propiedad de los archivos al usuario `root`. Este problema se puede solucionar de distintas formas:
#
# * Asignando permisos de escritura a todos los usuarios (comando `chmod` en Linux).
# * Usando el comando `sudo`.
# * Copiando el archivo desde el anfitrión al contenedor con el comando `cp` de `docker`:
# ```bash
# docker cp Tarea\ para\ BDA01.ipynb namenode:/media/notebooks/unidad\ 1/
# ```
# * Si todo lo anterior no funciona, pregunta en el foro.
#
# Una vez tengas la plantilla de la tarea en el servidor de Jupyter, comienza a completar las celdas que empiecen por "TODO".

# %% [markdown]
# ### 1.- Instala `docker` y `docker-compose` en tu equipo y copia una imagen en la que se muestre el resultado de ejecutar en el anfitrión las siguientes instrucciones:
#
# ```bash
# docker --version
# docker-compose --version
# ```

# %% [markdown]
# ![docker version](./images/docker_version.png)
# ![docker-compose version](./images/docker_compose_version.png)

# %% [markdown]
# ### 2.- Levanta el entorno de Hadoop con `docker-compose` haciendo lo que se indica en la guía práctica.

# %% [markdown]
# ![docker-compose up](./images/docker_compose_up.png)

# %% [markdown]
# ### 3.- Muestra en Jupyter el contenido del directorio en el que estás ejecutando este libro.

# %% [markdown]
# ![jupyter listado](./images/jupyter_listado.png)

# %% [markdown]
# ### 4.- Realiza todo el proceso que se describe en la guía práctica para obtener el número de palabras que contiene *El Quijote*.

# %%
# !wget https://www.gutenberg.org/files/2000/2000-0.txt
# Out:
# --2025-11-18 23:00:24--  https://www.gutenberg.org/files/2000/2000-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2226045 (2.1M) [text/plain]
# Saving to: ‘2000-0.txt’
#
# 2000-0.txt          100%[===================>]   2.12M  2.34MB/s    in 0.9s
#
# 2025-11-18 23:00:26 (2.34 MB/s) - ‘2000-0.txt’ saved [2226045/2226045]

# %%
import re

with open('./2000-0.txt') as f:
    lines = f.readlines()
    
head = 24
tail = 360

book = lines[head:-tail]
book = "".join(book)
book = book.lower()
book = re.split('\W', book)

filtered_book = list(filter(lambda word: word  != '', book))
word_count = len(filtered_book)

print(f'El Quijote tiene {word_count} palabras')
# Out:
# El Quijote tiene 383640 palabras

# %% [markdown]
# ### 5.- Crea un proceso en Python que muestre las 10 palabras que más se utilizan en *El Quijote* junto con el número de veces que aparecen en el libro.
#
# Los ejercicios anteriores pretendían simplemente que replicaras el trabajo que se realizó en la guía práctica. Este ejercicio tiene como objetivo que empieces a crear tus primeros programas en Python para que te resulten más fáciles las próximas prácticas.

# %%
from collections import Counter

word_counts = Counter(book)
ordered_word_counts =  dict(sorted(word_counts.items(), key=lambda x: x[1], reverse=True))
top_10_words = list(ordered_word_counts.items())[:10]

print(
    "Las 10 palabras que más se utilizan en el Quijote y el número de veces que aparece en el libro:\n", 
    top_10_words, 
    sep="\n",
)
# Out:
# Las 10 palabras que más se utilizan en el Quijote y el número de veces que aparece en el libro:
#
# [('', 75755), ('que', 20769), ('de', 18410), ('y', 18272), ('la', 10492), ('a', 9876), ('en', 8285), ('el', 8265), ('no', 6346), ('los', 4769)]

# %% [markdown]
# ### 6.- (OPCIONAL) Los dos últimos ejercicios son tareas habituales en el mundo de Big Data, concretamente pertenecen a un área denominada Procesamiento de Lenguaje Natural (NLP). Sin embargo, la solución que se pidió es trivial y tiene bastantes problemas para ser aplicada en un entorno profesional:
#
# * Por un lado no admite trabajar con un gran volumen de datos. De esto nos ocuparemos en próximas prácticas ya que este es el problema esencial al que tratamos de dar solución en este módulo.
# * Por otro, tanto la división en palabras (ejercicio 4), como el cálculo de la frecuencia de aparición (ejercicio 5), hacen suposiciones poco realistas: Para la división en palabras hemos supuesto que cualquier carácter no alfanumérico sirve para separar dos palabras, pero esto no es siempre cierto. Por ejemplo, ¿cuántas palabras hay en O.T.A.N.?, ¿cinco o una? Además, para contar las palabras más frecuentes no hemos tenido en cuenta que una misma palabra se puede presentar en diferentes formas. Por ejemplo: "la" y "las", ¿son la misma palabra o dos palabras diferentes?, ¿y "fue" e "irá"? La respuesta a esta pregunta no es unívoca y dependerá del objetivo del estudio.
#
# Las herramientas de NLP nos permiten tanto dividir un texto en palabras ("tokenization"), como
# obtener el [lema](https://es.wikipedia.org/wiki/Lema_(ling%C3%BC%C3%ADstica)#:~:text=El%20lema%20es%20la%20unidad,o%20no%2C%20de%20un%20lema.) de una palabra ("lemmatisation"). En este ejercicio se pretende que resuelvas los ejercicios 4 y 5 usando [`spaCy`](https://spacy.io/), que es una herramienta NLP popular en el mundo Python. Dado que se trata de una actividad voluntaria y para hacerlo más interesante, no se va a dar ninguna indicación de cómo realizar el proceso. Incluso aunque no llegues a resolver el ejercicio, es interesante que consultes la solución cuando esta se publique.

# %% [markdown]
# TODO: Utiliza `spaCy` para resolver los ejercicios 3 y 4. Sustituye esta celda por la solución.

# %%
# Para instalar spaCy en el contenedor de Jupyter, ejecuta la siguiente instrucción

# !pip install "spacy<3.8"

# Para descargar el tokenizer de spaCy en español

# !pip install https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl
# Out:
# Requirement already satisfied: spacy<3.8 in /usr/local/lib/python3.8/dist-packages (3.7.5)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (8.2.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (3.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (3.0.12)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (0.4.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (2.0.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (2.32.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (1.1.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (2.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from spacy<3.8) (2.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (1.0.15)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (0.20.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.8) (45.2.0)
# Requirement already satisfied: numpy>=1.15.0; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (1.24.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (3.0.12)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8) (25.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8) (0.1.5)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.8/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8) (1.3.0)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8) (0.20.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8) (7.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8) (2025.11.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8) (3.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8) (4.13.2)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8) (2.27.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.8/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8) (8.1.8)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.8/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8) (14.2.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8) (1.2.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8) (2.0.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8) (0.1.2)
# Requirement already satisfied: es-core-news-sm==3.7.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl in /usr/local/lib/python3.8/dist-packages (3.7.0)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.8/dist-packages (from es-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (25.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (45.2.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.32.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.15)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: numpy>=1.15.0; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.24.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: confection<0.2.0,>=0.0.4 in /usr/local/lib/python3.8/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (7.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.8/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2025.11.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.2.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.13.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.8/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.8/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (14.2.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.2)

# %%
import spacy

nlp = spacy.load("es_core_news_sm")

with open('./2000-0.txt') as f:
    lines = f.readlines()

book = lines[head:-tail]
book = "".join(book)

chunk_size = 1000000
chunks = [book[i:i+chunk_size] for i in range(0, len(book), chunk_size)]

spicy_filtered_book = []

for chunk in chunks:
    doc = nlp(chunk)
    spicy_filtered_book.extend(
        token.lemma_.lower()
        for token in doc
        if token.is_alpha and not token.is_stop
    )
    
spicy_words_count = len(spicy_filtered_book)

print(f'Con spaCy El Quijote tiene {spicy_words_count} palabras')
# Out:
# Con spaCy El Quijote tiene 145958 palabras

# %%
from collections import Counter

counter = Counter(spicy_filtered_book)
spacy_top_10_words_sorted = counter.most_common()[:10]

print(    
"""Las 10 palabras que más se utilizan en el Quijote y el número de veces que aparece en el libro, filtrado con spacy:\n""",
    spacy_top_10_words_sorted,
    sep="\n"
)
# Out:
# Las 10 palabras que más se utilizan en el Quijote y el número de veces que aparece en el libro, filtrado con spacy:
#
# [('don', 2720), ('quijote', 2241), ('sancho', 2176), ('responder', 1222), ('señor', 1190), ('ver', 1059), ('decir', 1042), ('merced', 967), ('caballero', 966), ('querer', 935)]
